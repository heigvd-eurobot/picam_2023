# %%
from cakeDetector import cakeDetector2 as cd
import cv2
cv2.__version__
# Out:
# '4.7.0'

# %%
import matplotlib.pyplot as plt
coco = cd.CakeDetector()

img = cv2.imread('pistouk_portrait.png')

# %%
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()

ret, frame = cap.read()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(frame)

cap.release()

# %%
print(frame.shape, img.shape)
# Out:
# (480, 640, 3) (9152, 6944, 3)

# %%
coco.initDetector(img)
coco.detectCakes(img)
# Out:
# [{'x': 950.419307667469,
#   'y': 981.3855065295966,
#   'layers': [2],
#   'hasCherry': False},
#  {'x': 518.2812359407749,
#   'y': 964.3060407241582,
#   'layers': [2],
#   'hasCherry': False},
#  {'x': 501.1841900269806,
#   'y': 569.8401212275244,
#   'layers': [0],
#   'hasCherry': False},
#  {'x': 161.78624355100385,
#   'y': 547.4352230503019,
#   'layers': [0],
#   'hasCherry': False},
#  {'x': 627.3387067983508,
#   'y': 1708.772470733594,
#   'layers': [0, 2, 1],
#   'hasCherry': False},
#  {'x': 433.7421450575726,
#   'y': 1886.882086824234,
#   'layers': [2, 0],
#   'hasCherry': False},
#  {'x': 493.189083837409,
#   'y': 1497.936096577901,
#   'layers': [2, 1],
#   'hasCherry': False},
#  {'x': 285.69143993062755,
#   'y': 1998.9561418458163,
#   'layers': [1, 0],
#   'hasCherry': False},
#  {'x': 189.19802676405715,
#   'y': 1225.3515513749605,
#   'layers': [0],
#   'hasCherry': False},
#  {'x': 173.82204315810026,
#   'y': 1408.2464604938675,
#   'layers': [1, 2],
#   'hasCherry': False},
#  {'x': 1449.90098001517,
#   'y': 527.3879932627167,
#   'layers': [0],
#   'hasCherry': False},
#  {'x': 1559.1366625487185,
#   'y': 1021.6528195938313,
#   'layers': [2],
#   'hasCherry': False},
#  {'x': 1680.9304935479727,
#   'y': 1465.3866457293575,
#   'layers': [1],
#   'hasCherry': False},
#  {'x': 2715.3014194294883,
#   'y': 708.3769994200269,
#   'layers': [0],
#   'hasCherry': False},
#  {'x': 2607.829065995084,
#   'y': 1000.0995003786572,
#   'layers': [2],
#   'hasCherry': False},
#  {'x': 2726.457336422579,
#   'y': 1246.3141339430904,
#   'layers': [1],
#   'hasCherry': False}]
