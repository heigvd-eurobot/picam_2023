# %%
from cakeDetector import cakeDetector2 as cd
import cv2
cv2.__version__
# Out:
# '4.6.0'

# %%
import matplotlib.pyplot as plt
coco = cd.CakeDetector()

img = cv2.imread('pistouk_portrait.png')

# %%
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    exit()

ret, frame = cap.read()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(frame)

cap.release()
# Out:
# [ WARN:0@2.692] global /work/ci_py311/opencv-suite_1676837327081/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created

# %%
print(frame.shape, img.shape)
# Out:
# (480, 640, 3) (9152, 6944, 3)

# %%
coco.initDetector(img)
coco.detectCakes(img)
# Out:
# [{'x': 950.4943428202401,
#   'y': 980.2350940259181,
#   'layers': [2],
#   'hasCherry': False},
#  {'x': 633.5683070236458,
#   'y': 791.3359865714132,
#   'layers': [0],
#   'hasCherry': False},
#  {'x': 518.489833459672,
#   'y': 965.0874824794014,
#   'layers': [2],
#   'hasCherry': False},
#  {'x': 500.3606588929397,
#   'y': 571.2971370388838,
#   'layers': [0],
#   'hasCherry': False},
#  {'x': 259.10559685056387,
#   'y': 862.558477139001,
#   'layers': [2],
#   'hasCherry': False},
#  {'x': 628.0795375140839,
#   'y': 1708.857150914261,
#   'layers': [0, 2, 1],
#   'hasCherry': False},
#  {'x': 433.9476885044884,
#   'y': 1887.3364316211816,
#   'layers': [2, 0],
#   'hasCherry': False},
#  {'x': 493.189083837409,
#   'y': 1497.936096577901,
#   'layers': [2, 1],
#   'hasCherry': False},
#  {'x': 286.1677748836112,
#   'y': 1999.3107230654402,
#   'layers': [1, 0],
#   'hasCherry': False},
#  {'x': 173.82204315810026,
#   'y': 1408.2464604938675,
#   'layers': [1, 2],
#   'hasCherry': False},
#  {'x': 1559.1366625487185,
#   'y': 1021.6528195938313,
#   'layers': [2],
#   'hasCherry': False},
#  {'x': 1449.90098001517,
#   'y': 527.3879932627167,
#   'layers': [0],
#   'hasCherry': False},
#  {'x': 1680.9304935479727,
#   'y': 1465.3866457293575,
#   'layers': [1],
#   'hasCherry': False},
#  {'x': 2715.3014194294883,
#   'y': 708.3769994200269,
#   'layers': [0],
#   'hasCherry': False},
#  {'x': 2607.829065995084,
#   'y': 1000.0995003786572,
#   'layers': [2],
#   'hasCherry': False},
#  {'x': 2726.457336422579,
#   'y': 1246.3141339430904,
#   'layers': [1],
#   'hasCherry': False}]
